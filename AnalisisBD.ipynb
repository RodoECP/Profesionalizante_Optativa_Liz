# %% [markdown]
# <a href="https://colab.research.google.com/github/RodoECP/Profesionalizante_Optativa_Liz/blob/main/AnalisisBD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install numpy pandas scikit-learn matplotlib
# Ignorar advertencias
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px

dataset = pd.read_csv('https://raw.githubusercontent.com/RodoECP/Profesionalizante_Optativa_Liz/refs/heads/main/student_performance.csv', sep = ',' )

dataset.head()
numeric_columns = ['AttendanceRate', 'StudyHoursPerWeek','PreviousGrade','ExtracurricularActivities','FinalGrade']
for column in numeric_columns:
  print(f"\n{column}:")
  print(f"Media: {dataset[column].mean():.2f}")
  print(f"Mediana: {dataset[column].median()}")
  print(f"Moda: {dataset[column].mode()}")
  print(f"Desviacion Estandar: {dataset[column].std()}")
  print(f"Valor mínimo: {dataset[column].min()}")
  print(f"Valor máximo: {dataset[column].max()}")
  print(f"Cuartiles: \n{dataset[column].quantile([0.25, 0.5, 0.75])}")
# Out:
# AttendanceRate:
# Media: 85.60
# Mediana: 86.5
# ModaL 0    85
# Name: AttendanceRate, dtype: int64
# Desviacion Estandar: 7.441624673267107
# Valor mínimo: 70
# Valor máximo: 95
# Cuartiles:
# 0.25    82.75
# 0.50    86.50
# 0.75    90.75
# Name: AttendanceRate, dtype: float64
#
# StudyHoursPerWeek:
# Media: 17.70
# Mediana: 17.5
# ModaL 0     8
# 1    10
# 2    12
# 3    15
# 4    17
# 5    18
# 6    20
# 7    22
# 8    25
# 9    30
# Name: StudyHoursPerWeek, dtype: int64
# Desviacion Estandar: 6.848357467305573
# Valor mínimo: 8
# Valor máximo: 30
# Cuartiles:
# 0.25    12.75
# 0.50    17.50
# 0.75    21.50
# Name: StudyHoursPerWeek, dtype: float64
#
# PreviousGrade:
# Media: 78.10
# Mediana: 80.0
# ModaL 0    60
# 1    65
# 2    70
# 3    77
# 4    78
# 5    82
# 6    85
# 7    86
# 8    88
# 9    90
# Name: PreviousGrade, dtype: int64
# Desviacion Estandar: 10.170217958988555
# Valor mínimo: 60
# Valor máximo: 90
# Cuartiles:
# 0.25    71.75
# 0.50    80.00
# 0.75    85.75
# ...
